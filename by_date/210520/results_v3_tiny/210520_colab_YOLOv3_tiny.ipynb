# %%
# !nvidia-smi                             # GPU 정보 확인
# !head /proc/cpuinfo                     # CPU 정보 확인
# !/usr/local/cuda/bin/nvcc --version     # CUDA 정보 확인
# Out:
# Thu May 20 00:41:47 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 465.19.01    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   35C    P0    27W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# 구글드라이브 마운트
from google.colab import drive
drive.mount('/content/drive')

# %%
# (안함) cuDNN 설치 파일 경로로 이동
# cd (경로)

# %%
# (안함) cuDNN 설치
# !tar -xzvf cudnn-11.0-linux-x64-v8.0.5.39.tgz -C /usr/local/

# %%
# (안함) cuDNN 설치 확인
# !chmod a+r /usr/local/cuda/include/cudnn.h
# !cat /usr/local/cuda/include/cudnn.h | grep CUDNN_MAJOR -A 2

# %% [markdown]
# # darknet 설치
# - YOLOv4 튜토리얼 코드 그대로 사용
# - 파일 경로들만 조금 다름

# %%
# darknet 설치하려는 경로로 이동
# 본인 구글 드라이브 內
# %cd /content/drive/Shareddrives/mulcam_ai/yolov3_tiny
# Out:
# /content/drive/Shareddrives/mulcam_ai/yolov3_tiny

# %%
# darknet 설치
# !git clone https://github.com/AlexeyAB/darknet

# %%
# %cd darknet
# !sed -i 's/OPENCV=0/OPENCV=1/' Makefile
# !sed -i 's/GPU=0/GPU=1/' Makefile
# !sed -i 's/CUDNN=0/CUDNN=1/' Makefile
# !sed -i 's/CUDNN_HALF=0/CUDNN_HALF=1/' Makefile
# cuDNN_HALF는 NVIDIA 상위 GPU 기종에서 사용가능

# %%
# !make

# %% [markdown]
# ## 선택사항

# %%
# 결과물 확인 등을 위한 함수 정의
# define helper functions
def imShow(path):
  import cv2
  import matplotlib.pyplot as plt
  # %matplotlib inline

  image = cv2.imread(path)
  height, width = image.shape[:2]
  resized_image = cv2.resize(image,(3*width, 3*height), interpolation = cv2.INTER_CUBIC)

  fig = plt.gcf()
  fig.set_size_inches(18, 10)
  plt.axis("off")
  plt.imshow(cv2.cvtColor(resized_image, cv2.COLOR_BGR2RGB))
  plt.show()

# use this to upload files
def upload():
  from google.colab import files
  uploaded = files.upload() 
  for name, data in uploaded.items():
    with open(name, 'wb') as f:
      f.write(data)
      print ('saved file', name)

# use this to download a file  
def download(path):
  from google.colab import files
  files.download(path)

# %% [markdown]
# # 튜토리얼

# %%
# 튜토리얼을 위한 weights 파일 다운로드
# !wget https://github.com/AlexeyAB/darknet/releases/download/darknet_yolo_v3_optimal/yolov4.weights

# %%
# 기본 테스트 이미지(person) 사용
# !./darknet detector test cfg/coco.data cfg/yolov4.cfg yolov4.weights data/person.jpg

# %%
# show image using our helper function
imShow('predictions.jpg')

# %% [markdown]
# # Custom Training

# %%
# %cd /content/drive/Shareddrives/mulcam_ai/yolov3_tiny/darknet/data
# Out:
# /content/drive/Shareddrives/mulcam_ai/yolov3_tiny/darknet/data

# %%
# !git clone https://github.com/EyesOn-FinalProject/bus_img.git
# Out:
# Cloning into 'bus_img'...
# remote: Enumerating objects: 2605, done.
# remote: Counting objects: 100% (8/8), done.
# remote: Compressing objects: 100% (7/7), done.
# remote: Total 2605 (delta 1), reused 8 (delta 1), pack-reused 2597
# Receiving objects: 100% (2605/2605), 318.54 MiB | 24.71 MiB/s, done.
# Resolving deltas: 100% (1/1), done.
# Checking out files: 100% (2598/2598), done.

# %%
# %cd /content/drive/Shareddrives/mulcam_ai/yolov3_tiny/darknet
# Out:
# /content/drive/Shareddrives/mulcam_ai/yolov3_tiny/darknet

# %%
# 아래 코드 실행 시
# /bin/bash: ./darknet: Permission denied 에러 발생하면 아래 코드 실행
# !chmod +x ./darknet

# %%
# 기존 weights 파일에서 custom train을 위한 weights 파일 추출
# !./darknet partial cfg/yolov3-tiny.cfg yolov3-tiny.weights yolov3-tiny.conv.15 15

# %%
# ./darknet detector train <.data> <.cfg> <.weights> -dont_show -map
# !./darknet detector train cfg/obj.data cfg/yolov3-tiny-obj.cfg yolov3-tiny.conv.15 -dont_show -map
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.836163), count: 3, class_loss = 0.029261, iou_loss = 0.063334, total_loss = 0.092595
#  total_bbox = 1334022, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.849839), count: 9, class_loss = 0.245990, iou_loss = 0.201289, total_loss = 0.447280
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.780947), count: 1, class_loss = 0.011989, iou_loss = 0.030943, total_loss = 0.042931
#  total_bbox = 1334032, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.909933), count: 4, class_loss = 0.110876, iou_loss = 0.012077, total_loss = 0.122953
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.862462), count: 3, class_loss = 0.232285, iou_loss = 0.034990, total_loss = 0.267275
# ...

# %% [markdown]
# # Test

# %%
# !./darknet detector demo cfg/obj.data cfg/yolov3-tiny-obj.cfg backup/yolov3-tiny-obj_best.weights data/green_test2.mp4 -dont_show -out_filename green_test2_out_0520_v3_tiny_best.avi

# %%
# !./darknet detector demo cfg/obj.data cfg/yolov3-tiny-obj.cfg backup/yolov3-tiny-obj_last.weights data/green_test2.mp4 -dont_show -out_filename green_test2_out_0520_v3_tiny_last.avi
# Out:
#  CUDA-version: 11000 (11020), cuDNN: 7.6.5, CUDNN_HALF=1, GPU count: 1
#  CUDNN_HALF=1
#  OpenCV version: 3.2.0
# Demo
#  0 : compute_capability = 600, cudnn_half = 0, GPU: Tesla P100-PCIE-16GB
# net.optimized_memory = 0
# mini_batch = 1, batch = 16, time_steps = 1, train = 0
#    layer   filters  size/strd(dil)      input                output
#    0 Create CUDA-stream - 0
#  Create cudnn-handle 0
# conv     16       3 x 3/ 1    416 x 416 x   3 ->  416 x 416 x  16 0.150 BF
#    1 max                2x 2/ 2    416 x 416 x  16 ->  208 x 208 x  16 0.003 BF
#    2 conv     32       3 x 3/ 1    208 x 208 x  16 ->  208 x 208 x  32 0.399 BF
#    3 max                2x 2/ 2    208 x 208 x  32 ->  104 x 104 x  32 0.001 BF
#    4 conv     64       3 x 3/ 1    104 x 104 x  32 ->  104 x 104 x  64 0.399 BF
#    5 max                2x 2/ 2    104 x 104 x  64 ->   52 x  52 x  64 0.001 BF
#    6 conv    128       3 x 3/ 1     52 x  52 x  64 ->   52 x  52 x 128 0.399 BF
# ...
