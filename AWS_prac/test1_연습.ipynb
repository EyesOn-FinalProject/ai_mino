# %%
import tensorflow as tf

# %%
tf.__version__
# Out:
# '1.14.0'

# %%
cd darkflow
# Out:
# /home/lab19/darkflow

# %%
# 구동되는 모델. YOLOv2 608x608
# weights 파일 - https://pjreddie.com/darknet/yolo/
# !flow --imgdir sample_img/ --model cfg/yolov2.cfg --load bin/yolov2.weights --gpu 1.0
# Out:
# /home/lab19/.conda/envs/mino1/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/lab19/.conda/envs/mino1/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/lab19/.conda/envs/mino1/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# ...

# %%
# 결과물 이미지 + json(좌표 데이터) 반환
# !flow --imgdir sample_img/ --model cfg/yolov2.cfg --load bin/yolov2.weights --gpu 1.0 --json
# Out:
# /home/lab19/.conda/envs/mino1/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/lab19/.conda/envs/mino1/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/lab19/.conda/envs/mino1/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# ...

# %%
# 안됨.
# AssertionError: expect 44948596 bytes, found 44948600
# 이 오류 loader.py line121 수정했는데도(stackoverflow 참고) 안됨. 외않돼는지 이해가 안감.
# !flow --imgdir sample_img/ --model cfg/yolov2-tiny.cfg --load bin/yolov2-tiny.weights --gpu 1.0
# Out:
# /home/lab19/.conda/envs/mino1/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/lab19/.conda/envs/mino1/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/lab19/.conda/envs/mino1/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# ...

# %%
# 안됨.
# 위와 마찬가지 이유로 안되는데, 고치질 못함. pb 파일로 바꾸면 된다는 문서가 있어서 시도해볼 예정.
# !flow --imgdir sample_img/ --model cfg/tiny-yolo.cfg --load bin/yolo-tiny.weights --gpu 1.0
# Out:
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# WARNING:tensorflow:From /home/lab19/.conda/envs/mino1/lib/python3.7/site-packages/darkflow/net/build.py:15: The name tf.train.RMSPropOptimizer is deprecated. Please use tf.compat.v1.train.RMSPropOptimizer instead.
#
# WARNING:tensorflow:From /home/lab19/.conda/envs/mino1/lib/python3.7/site-packages/darkflow/net/build.py:16: The name tf.train.AdadeltaOptimizer is deprecated. Please use tf.compat.v1.train.AdadeltaOptimizer instead.
#
# ...
