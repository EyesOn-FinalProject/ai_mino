# %%
#-*- coding:utf-8 -*-
import os
import sys

CURRENT_DIR = os.getcwd()

def progressBar(value, endvalue, bar_length=20):
  percent = float(value) / endvalue
  arrow = '-' * int(round(percent * bar_length)-1) + '>'
  spaces = ' ' * (bar_length - len(arrow))

  sys.stdout.write("\rPercent: [{0}] {1}%".format(arrow + spaces, int(round(percent * 100))))
  sys.stdout.flush()

def returnFileList(dirname, extract):
  fileList = []
  filenames = os.listdir(dirname)
  for filename in filenames:
    ext = os.path.splitext(filename)[-1]
    if ext == extract: 
      fileList.append(filename)
  return fileList

with open("./list.txt","w") as fileList:
  fileNames = returnFileList(CURRENT_DIR, ".jpg")
  
  for i, fileName in enumerate(fileNames):
#     fileList.write(CURRENT_DIR+"\\"+fileName+"\n") -> 원래 코드인데 파일 이름 앞에 역슬래쉬 생겨서 오류 떴음.
#     fileList.write(CURRENT_DIR+"/"+fileName+"\n")
    fileList.write("data/"+"bus_img/"+fileName+"\n")
    progressBar(i, len(fileNames), bar_length=100)
# Out:
# Percent: [--------------------------------------------------------------------------------------------------->] 100%

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/MyDrive/AI/[프로젝트] 융복합_9조/AI모델/210515_colab_kriyeng/darknet/data/bus_img
# Out:
# /content/drive/MyDrive/AI/[프로젝트] 융복합_9조/AI모델/210515_colab_kriyeng/darknet/data/bus_img
